# %% [markdown]
# # LGMVIP - Data Science Intern
# # Task - 1
# # Iris Flower Classification ML Project
# # Name - Muskan Sogani

# %% [markdown]
# # Importing the required libraries

# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing the DataSet

# %%
df= pd.read_csv('iris_csv.csv')

# %%
df.head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# # Displaying Iris Flower

# %%
from PIL import Image
iris_image = Image.open('iris_image.jpg')
iris_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=265x190 at 0x14903AF4D30>

# %% [markdown]
# # Displaying the statistics of the dataset

# %%
df.describe()
# Out:
#        sepallength  sepalwidth  petallength  petalwidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
df.info
# Out:
# <bound method DataFrame.info of      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %% [markdown]
# # Renaming the 'class' as 'species'

# %%
df.columns = ['sepallength','sepalwidth','petallength','petalwidth','species']
df.head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth      species
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# # Displaying the number of samples

# %%
df['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %% [markdown]
# # Getting the maximum values

# %%
df.max()
# Out:
# sepallength               7.9
# sepalwidth                4.4
# petallength               6.9
# petalwidth                2.5
# species        Iris-virginica
# dtype: object

# %% [markdown]
# # Getting the minimum values

# %%
df.min()
# Out:
# sepallength            4.3
# sepalwidth             2.0
# petallength            1.0
# petalwidth             0.1
# species        Iris-setosa
# dtype: object

# %% [markdown]
# # Preprocessing our dataset

# %% [markdown]
# # Check if null values are present

# %%
df.isnull().sum()
# Out:
# sepallength    0
# sepalwidth     0
# petallength    0
# petalwidth     0
# species        0
# dtype: int64

# %%
df.isnull()
# Out:
#      sepallength  sepalwidth  petallength  petalwidth  species
# 0          False       False        False       False    False
# 1          False       False        False       False    False
# 2          False       False        False       False    False
# 3          False       False        False       False    False
# 4          False       False        False       False    False
# ..           ...         ...          ...         ...      ...
# 145        False       False        False       False    False
# 146        False       False        False       False    False
# 147        False       False        False       False    False
# 148        False       False        False       False    False
# 149        False       False        False       False    False
#
# [150 rows x 5 columns]

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Making a  bar plot

# %%
name = list(df['species'].value_counts().keys())
number = list(df['species'].value_counts())
sns.set(rc={'figure.figsize':(20,20)})
sns.barplot(x=name,y=number,data = df,hue=name)
plt.xlabel('\nSpecies')
plt.ylabel('Counts')
plt.show()

# %% [markdown]
# # Making a sub plots between sepal lenght, petal length and species

# %%
plt.subplot(1,2,1)
sns.set(rc={'figure.figsize':(25,25)})
sns.barplot(x='species',y='petallength',data=df,hue='species')
plt.title("Petal Length")

plt.subplot(1,2,2)
sns.set(rc={'figure.figsize':(25,25)})
sns.barplot(x='species',y='sepallength',data=df,hue='species')
plt.title("Sepal Length")
plt.show()

# %% [markdown]
# # Making a Subplots between petal width, sepal width and species

# %%
plt.subplot(1,2,1)
sns.set(rc={'figure.figsize':(25,25)})
sns.barplot(x='species',y='petalwidth',data=df,hue='species')
plt.title("Petal Width")

plt.subplot(1,2,2)
sns.set(rc={'figure.figsize':(25,25)})
sns.barplot(x='species',y='sepalwidth',data=df,hue='species')
plt.title("Sepal Width")
plt.show()

# %% [markdown]
# # Making a Scatter Plot of Sepal length and Petal length of given species

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.scatterplot(x='sepallength',y='petallength',data=df,hue='species',style='species',s=100)
plt.title("Sepal and Petal length of given species")
plt.show()

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.scatterplot(x='sepalwidth',y='petalwidth',data=df,hue='species',style='species',s=100)
plt.title("Sepal and Petal width of given species")
plt.show()

# %% [markdown]
# # Making Pairplots

# %%
sns.pairplot (df,hue='species')
plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
df.corr()
# Out:
#              sepallength  sepalwidth  petallength  petalwidth
# sepallength     1.000000   -0.109369     0.871754    0.817954
# sepalwidth     -0.109369    1.000000    -0.420516   -0.356544
# petallength     0.871754   -0.420516     1.000000    0.962757
# petalwidth      0.817954   -0.356544     0.962757    1.000000

# %% [markdown]
# # Heat Map

# %%
corr = df.corr()
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(corr,annot=True,ax=ax)
plt.show()

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['species']=le.fit_transform(df['species'])
df.head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth  species
# 0          5.1         3.5          1.4         0.2        0
# 1          4.9         3.0          1.4         0.2        0
# 2          4.7         3.2          1.3         0.2        0
# 3          4.6         3.1          1.5         0.2        0
# 4          5.0         3.6          1.4         0.2        0

# %% [markdown]
# # Making Train/test

# %%
from sklearn.model_selection import train_test_split
s=df.drop(columns=['species'])
t=df['species']
x_train,x_test,y_train,y_test=train_test_split(s,t,test_size=0.3)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %% [markdown]
# # Getting the accuracy

# %%
print("The accuracy is :",lr.score(x_test,y_test)*100)
# Out:
# The accuracy is : 93.15497128162963

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Calculating the Mean Squared Error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.04854054933125852

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
Lr1 = LogisticRegression()

# %%
from sklearn.model_selection import train_test_split
u=df.drop(columns=['species'])
v=df['species']
x1_train,x1_test,y1_train,y1_test=train_test_split(u,v,test_size=0.3)

# %%
Lr1.fit(x1_train,y1_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = Lr1.predict (x1_test)

# %% [markdown]
# # Getting the accuracy

# %%
print("The accuracy is :",Lr1.score(x1_test,y1_test)*100)
# Out:
# The accuracy is : 95.55555555555556

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Calculating the Mean Squared Error

# %%
mean_squared_error(y1_test,y_pred1)
# Out:
# 0.044444444444444446

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
from sklearn.model_selection import train_test_split
p=df.drop(columns=['species'])
q=df['species']
x2_train,x2_test,y2_train,y2_test=train_test_split(p,q,test_size=0.3)

# %%
dt.fit (x2_train,y2_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = dt.predict (x2_test)

# %% [markdown]
# # Getting the Accuracy

# %%
print("The accuracy is :",dt.score(x2_test,y2_test)*100)
# Out:
# The accuracy is : 93.33333333333333

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Calculating the Mean Squared Error

# %%
mean_squared_error(y2_test,y_pred2)
# Out:
# 0.06666666666666667

# %% [markdown]
# # KNeighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
from sklearn.model_selection import train_test_split
n=df.drop(columns=['species'])
m=df['species']
x3_train,x3_test,y3_train,y3_test=train_test_split(n,m,test_size=0.3)

# %%
knn.fit (x3_train,y3_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred3 = knn.predict (x3_test)

# %% [markdown]
# # Getting the Accuracy

# %%
print("The accuracy is :",knn.score(x3_test,y3_test)*100)
# Out:
# The accuracy is : 95.55555555555556

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Calculating Mean Squared Error

# %%
mean_squared_error(y3_test,y_pred3)
# Out:
# 0.044444444444444446

# %% [markdown]
# # Thank You!
